# %%
import pandas as pd
import json

with open('conso.json', 'r') as json_file:
    data = json.load(json_file)

df = pd.DataFrame(data)
df.head()
# Out:
#                   date_heure        date  heure  \
# 0  2023-06-30T23:30:00+02:00  30/06/2023  23:30
# 1  2023-06-30T23:00:00+02:00  30/06/2023  23:00
# 2  2023-06-30T22:30:00+02:00  30/06/2023  22:30
# 3  2023-06-30T22:00:00+02:00  30/06/2023  22:00
# 4  2023-06-30T21:30:00+02:00  30/06/2023  21:30
#
#    consommation_brute_gaz_grtgaz    statut_grtgaz  \
# 0                            NaN             None
# 1                        21296.0  Meilleur Statut
# 2                            NaN             None
# 3                        23157.0  Meilleur Statut
# 4                            NaN             None
#
#    consommation_brute_gaz_terega statut_terega  consommation_brute_gaz_totale  \
# 0                            NaN          None                            NaN
# 1                         1112.0     Définitif                        22408.0
# 2                            NaN          None                            NaN
# ...
